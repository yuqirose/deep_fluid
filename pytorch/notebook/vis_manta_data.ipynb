# %%
import sys
sys.path.append("../data/")

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# %%
dir_path ="../data/sim_1001/"
# dat = np.load(dir_path+'density_low_0000.npz')
# img = dat['arr_0'].squeeze() # 1x64x64x3
img = Image.open(dir_path+'density_high_0000.ppm')
imgplot = plt.imshow(img)

# %%
num_frame = 120
x_dim = 64
y_dim = 64
n_chanel = 3

# %%
# %matplotlib notebook
import matplotlib.animation as animation
plt.rcParams["animation.html"] = "html5"
from IPython.display import HTML

fig = plt.figure()
ims = []
for i in range(num_frame):
    img_id = str(i).zfill(4)
    img = Image.open(dir_path+'density_high_'+img_id+'.ppm')
    im = plt.imshow(img, animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ani.save('dynamic_images.mp4')

# %%
# compare the npz/uni/ppm input 
sys.path.append("../../tensorflow/tools")
import uniio
dir_path ="../data/sim_1003/"

header, content = uniio.readUni(dir_path+'density_low_0000.uni')
h = header['dimX']
w  = header['dimY']
dat_uni = np.reshape(content, [w, h])
            

dat = np.load(dir_path+'density_low_0000.npz')
dat_npz = dat['arr_0'].squeeze() # 1x64x64x3

img = Image.open(dir_path+'density_low_0000.ppm')
dat_ppm = np.array(img.getdata()).reshape(w,h,3)

# %%
# %matplotlib inline
imgplot = plt.imshow(img)

# %%
print(dat_uni[25,30])
print(dat_npz[25,30])

print(dat_ppm.shape)
print(dat_ppm[25,30,:])

# %matplotlib inline
import scipy.misc
img2 = Image.fromarray(img_dat, 'RGB')
img_dat2 = np.array(img2)
imgplot2 = plt.imshow(img2)
print(img_dat2.shape)
# Out:
# 0.434566
# 0.434565961361
# (64, 64, 3)
# [0 0 0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-2b70b4d99fb5> in <module>()
#       7 get_ipython().magic(u'matplotlib inline')
#       8 import scipy.misc
# ----> 9 img2 = Image.fromarray(img_dat, 'RGB')
#      10 img_dat2 = np.array(img2)
#      11 imgplot2 = plt.imshow(img2)
#
# /usr/local/lib/python2.7/dist-packages/PIL/Image.pyc in fromarray(obj, mode)
#    2183     .. versionadded:: 1.1.6
#    2184     """
# -> 2185     arr = obj.__array_interface__
#    2186     shape = arr['shape']
#    2187     ndim = len(shape)
#
# AttributeError: 'ImagingCore' object has no attribute '__array_interface__'

# %%
# find the mean and std of the dataset
# mean:0.000149586382559
# std: 0.00882625011098

import numpy as np
data_path1 = "../../tensorflow/train_data/"
data_path2 ="../../tensorflow/test_data/"

mean_val = 0.0
for sim_num in range(1000, 1100):
    sim_id = str(sim_num).zfill(4)
    print(sim_id)
    for img_num in range(0, 100):
        mean_img_val = 0.0
        img_id = str(img_num).zfill(4)
        fname = data_path1+"sim_"+sim_id+"/pressure_low_"+img_id+".npz"
        img = np.load(fname)
        dat_true=img['arr_0'].squeeze()
        mean_img_val += np.std(dat_true)**2
    mean_val += mean_img_val/100
print(np.sqrt(mean_val/100))
# Out:
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 0.00882625011098
